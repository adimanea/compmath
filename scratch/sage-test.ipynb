# %%
plot3d?

# %%
u(n)=n^100 / 100^n

# %%
u(1.)
# Out:
# 0.0100000000000000

# %%
plot(u(x), x, 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e6b4a6aeb3c4> in <module>
# ----> 1 plot(u(x), x, Integer(40))
#
# /usr/lib/python3.8/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     491                 options['__original_opts'] = kwds
#     492             options.update(kwds)
# --> 493             return func(*args, **options)
#     494
#     495         #Add the options specified by @options to the signature of the wrapped
#
# /usr/lib/python3.8/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1958
#    1959     if hasattr(funcs, 'plot'):
# -> 1960         G = funcs.plot(*args, **original_opts)
#    1961
#    1962         # If we have extra keywords already set, then update them
#
# ...

# %%
plot(u(x), x, 1, 40)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n = var('n'); u = sin(pi*(sqrt(4*n^2+1)-2*n))

# %%
taylor(u, n, infinity, 3)
# Out:
# 1/4*pi/n - 1/384*(6*pi + pi^3)/n^3

# %%
# %display latex
